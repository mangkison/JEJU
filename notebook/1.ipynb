# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('../data/./wind_power/./Jeju Region Wind Power Hourly Performance (2019-12-01_2023-12-31).csv', encoding='cp949')
df.head(3)
# Out:
#            날짜       1시       2시       3시       4시       5시       6시       7시  \
# 0  2019-12-01   27.846   25.029   15.999   19.121   15.923   19.868   26.426
# 1  2019-12-02  256.605  245.428  228.624  229.361  226.257  242.204  226.189
# 2  2019-12-03  211.602  180.260  156.689  135.158  100.972   82.452   89.405
#
#         8시       9시  ...      15시      16시      17시      18시      19시  \
# 0   27.567   18.562  ...    7.212   15.670   28.882   43.144   63.484
# 1  209.256  188.624  ...  214.174  223.181  207.106  201.855  189.488
# 2   71.138   58.828  ...   77.223   62.469   69.759   47.194   53.583
#
#        20시      21시      22시      23시      24시
# 0  184.362  200.162  169.880  186.972  231.933
# 1  189.725  181.907  195.703  209.707  221.158
# 2   50.896   37.266   29.003   31.032   28.006
#
# [3 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# 날짜     0
# 1시     0
# 2시     0
# 3시     0
# 4시     0
# 5시     0
# 6시     0
# 7시     0
# 8시     0
# 9시     0
# 10시    0
# 11시    0
# 12시    0
# 13시    0
# 14시    0
# 15시    0
# 16시    0
# 17시    0
# 18시    0
# 19시    0
# 20시    0
# 21시    0
# 22시    0
# 23시    0
# 24시    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      1492 non-null   object
#  1   1시      1492 non-null   float64
#  2   2시      1492 non-null   float64
#  3   3시      1492 non-null   float64
#  4   4시      1492 non-null   float64
#  5   5시      1492 non-null   float64
#  6   6시      1492 non-null   float64
#  7   7시      1492 non-null   float64
#  8   8시      1492 non-null   float64
#  9   9시      1492 non-null   float64
#  10  10시     1492 non-null   float64
#  11  11시     1492 non-null   float64
#  12  12시     1492 non-null   float64
#  13  13시     1492 non-null   float64
#  14  14시     1492 non-null   float64
#  15  15시     1492 non-null   float64
#  16  16시     1492 non-null   float64
#  17  17시     1492 non-null   float64
#  18  18시     1492 non-null   float64
#  19  19시     1492 non-null   float64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 파일 경로
file_path = '../data/./wind_power/./Jeju Region Wind Power Hourly Performance (2019-12-01_2023-12-31).csv'
# 데이터 로드 (한글 인코딩 지원: cp949 사용)
try:
    data_2 = pd.read_csv(file_path, encoding='cp949')
except FileNotFoundError:
    print("파일 경로를 확인해주세요.")

# 한글 글꼴 설정
font_path = 'C:/Windows/Fonts/NanumGothicLight.ttf'  # 사용 가능한 한글 글꼴 경로
fontprop = fm.FontProperties(fname=font_path)

# 데이터를 긴 형식으로 변환 (시간대를 한 열로 묶음)
data_2_melted = data_2.melt(id_vars=["날짜"], var_name="시간", value_name="전력 생산량")

# 시간대별로 전력 생산량 평균 계산
hourly_mean_production = data_2_melted.groupby("시간")["전력 생산량"].mean()

# 시간대별 평균 전력 생산량을 막대그래프로 시각화
hourly_mean_production.plot(kind="bar", figsize=(12, 6))
plt.title("시간대별 평균 전력 생산량", fontsize=16)
plt.xlabel("시간", fontsize=14)
plt.ylabel("평균 전력 생산량 (kWh)", fontsize=14)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig('시각대별 평균 전력 생산량')
# 시간대별 평균 전력 생산량을 선 그래프로 시각화
plt.figure(figsize=(12, 6))
plt.plot(hourly_mean_production.index, hourly_mean_production.values, marker='o')
plt.title("시간대별 평균 전력 생산량", fontsize=16)
plt.xlabel("시간", fontsize=14)
plt.ylabel("평균 전력 생산량 (kWh)", fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig('시각대별 평균 전력 생산량')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# 파일 경로
file_path = '.'
# 데이터 로드 (한글 인코딩 지원: cp949 사용)
try:
    data_2 = pd.read_csv(file_path, encoding='cp949')
except FileNotFoundError:
    print("파일 경로를 확인해주세요.")

# 한글 글꼴 설정
font_path = 'C:/Windows/Fonts/NanumGothicLight.ttf'  # 사용 가능한 한글 글꼴 경로
fontprop = fm.FontProperties(fname=font_path)

# 데이터를 긴 형식으로 변환 (시간대를 한 열로 묶음)
data_2_melted = data_2.melt(id_vars=["날짜"], var_name="시간", value_name="전력 생산량")

# 시간대별로 전력 생산량 평균 계산
hourly_mean_production = data_2_melted.groupby("시간")["전력 생산량"].mean()

# 시간대별 평균 전력 생산량을 막대그래프로 시각화
hourly_mean_production.plot(kind="bar", figsize=(12, 6))
plt.title("시간대별 평균 전력 생산량", fontsize=16)
plt.xlabel("시간", fontsize=14)
plt.ylabel("평균 전력 생산량 (kWh)", fontsize=14)
plt.grid(axis='y')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig('시각대별 평균 전력 생산량')
# 시간대별 평균 전력 생산량을 선 그래프로 시각화
plt.figure(figsize=(12, 6))
plt.plot(hourly_mean_production.index, hourly_mean_production.values, marker='o')
plt.title("시간대별 평균 전력 생산량", fontsize=16)
plt.xlabel("시간", fontsize=14)
plt.ylabel("평균 전력 생산량 (kWh)", fontsize=14)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.savefig('시각대별 평균 전력 생산량')

# %%
from matplotlib import font_manager

# 사용 가능한 글꼴 목록 출력
fonts = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
print("사용 가능한 글꼴 목록:")
for font in fonts:
    print(font)
# Out:
# 사용 가능한 글꼴 목록:
# C:\Windows\Fonts\BOD_R.TTF
# C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# C:\Windows\Fonts\UnBatang.ttf
# C:\Windows\Fonts\LBRITE.TTF
# C:\Windows\Fonts\mmrtext.ttf
# C:\Windows\Fonts\timesbi.ttf
# C:\Windows\Fonts\FRSCRIPT.TTF
# C:\Windows\Fonts\CALISTB.TTF
# C:\Windows\Fonts\corbel.ttf
# C:\Windows\Fonts\CENTAUR.TTF
# C:\Windows\Fonts\Candara.ttf
# C:\Windows\Fonts\BIZ-UDMinchoM.ttc
# C:\Windows\Fonts\IMPRISHA.TTF
# C:\Windows\Fonts\DejaVuSansMono_0.ttf
# C:\Windows\Fonts\FORTE.TTF
# C:\Windows\Fonts\ebrima.ttf
# C:\Windows\Fonts\FRADM.TTF
# C:\Windows\Fonts\BELLB.TTF
# C:\Windows\Fonts\msjh.ttc
# C:\Windows\Fonts\segoeui.ttf
# C:\Windows\Fonts\BRLNSB.TTF
# C:\Windows\Fonts\FRAMDCN.TTF
# C:\Windows\Fonts\LEELAWAD.TTF
# C:\Windows\Fonts\gulim.ttc
# C:\Windows\Fonts\Nirmala.ttf
# C:\Windows\Fonts\STSONG.TTF
# C:\Windows\Fonts\calibrib.ttf
# C:\Windows\Fonts\bahnschrift.ttf
# C:\Windows\Fonts\seguili.ttf
# C:\Windows\Fonts\ebrimabd.ttf
# C:\Windows\Fonts\NanumGothicBold.ttf
# ...
